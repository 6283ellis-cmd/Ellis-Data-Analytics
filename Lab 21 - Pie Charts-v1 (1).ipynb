# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
#!wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv" 
# Load the data
df = pd.read_csv(url)

# Display the first few rows to understand the structure of the data
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
#color_names = list(mcolors.CSS4_COLORS.keys())
#print(color_names[10:500])

# %%
##Write your code here
# Split multiple values and explode into individual rows
db_df = df['DatabaseWantToWorkWith'].str.split(';').explode()

# Top 5 counts
top_5_db = db_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

# Define colors and explode the largest slice for emphasis
colors = ['lightsalmon','lavenderblush','lightcyan','lightgrey', 'lemonchiffon']
explode = (0.1, 0, 0, 0, 0) # Explode the 1st slice (top database)

plt.pie(
    top_5_db, 
    labels=top_5_db.index, 
    autopct='%1.1f%%', 
    startangle=0, 
    colors=colors, 
    explode=explode,
    shadow=True
)

plt.title('Top 5 Most Desired Databases')
plt.axis('equal') 
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
# Explode the roles to handle multiple entries per respondent
role_df = df['DevType'].str.split(';').explode()

top_5_roles = role_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['powderblue', 'thistle', 'moccasin', 'honeydew', 'lightgrey']

plt.pie(
    top_5_roles, 
    labels=top_5_roles.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors, 
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.5}
)

plt.title('Top 5 Developer Roles (DevType)')
plt.axis('equal') 
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %%
color_names = list(mcolors.CSS4_COLORS.keys())
#print(color_names[10:500])

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
import numpy as np

# %%
print(color_names[10:500])
# Out:
# ['blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'cyan', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow', 'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'lime', 'limegreen', 'linen
# ...

# %%
# Count and calculate percentages
opsys_df = df['OpSysProfessional use'].str.split(';').explode()
counts = opsys_df.value_counts()
percentages = (counts / counts.sum()) * 100

# Filter: Keep only those >= 1%
data_filtered = counts[percentages >= 1.0]

plt.figure(figsize=(10, 8))

colors = ['lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lavenderblush', 'lightslategrey', 'lightsteelblue', 'lightyellow','lightblue', 'lightcoral', 'lightcyan']

plt.pie(
    data_filtered, 
    labels=data_filtered.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    pctdistance=0.82, # Position percentages inside the ring
    wedgeprops={'edgecolor': 'white', 'linewidth': 2, 'width': 0.4} # 'width' creates the donut hole
)

plt.title('Professional OS Usage (Categories > 1%)', fontsize=15, pad=20)
plt.axis('equal') 

# note about the dropped data
plt.figtext(0.9, 0.1, f"Note: {len(counts) - len(data_filtered)} minor categories (<1%) excluded.", 
            horizontalalignment='right', fontsize=9, style='italic')

plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
lang_df = df['LanguageHaveWorkedWith'].str.split(';').explode()

top_5_lang = lang_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightskyblue', 'gold', 'lightcoral', 'yellowgreen', 'mediumpurple']

plt.pie(
    top_5_lang, 
    labels=top_5_lang.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

plt.title('Top 5 Programming Languages Worked With', fontsize=15)
plt.axis('equal') 
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
collab_df = df['NEWCollabToolsHaveWorkedWith'].str.split(';').explode()
top_5_collab = collab_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightskyblue', 'lightpink', 'palegreen', 'lightcoral', 'navajowhite']

plt.pie(
    top_5_collab, 
    labels=top_5_collab.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2} # Keeping the donut style
)

plt.title('Top 5 Collaboration Tools Used Professionally', fontsize=15, pad=20)
plt.axis('equal') 

plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
admired_lang_df = df['LanguageAdmired'].str.split(';').explode()
top_5_admired = admired_lang_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightgreen', 'lightskyblue', 'plum', 'lightsalmon', 'khaki']

plt.pie(
    top_5_admired, 
    labels=top_5_admired.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2} 
)

plt.title('Top 5 Most Admired Programming Languages', fontsize=15)
plt.axis('equal') 

plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
ai_tool_df = df['AIToolCurrently Using'].str.split(';').explode()
top_5_ai_tools = ai_tool_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightskyblue', 'lightcoral', 'palegreen', 'wheat', 'thistle']

plt.pie(
    top_5_ai_tools, 
    labels=top_5_ai_tools.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

plt.title('Top 5 AI Tools Currently Used for Development', fontsize=15, pad=20)
plt.axis('equal') 

plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
webframe_df = df['WebframeWantToWorkWith'].str.split(';').explode()
top_5_webframe = webframe_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightgreen', 'lightskyblue', 'lightpink', 'lightsalmon', 'lightcyan']

plt.pie(
    top_5_webframe, 
    labels=top_5_webframe.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

plt.title('Top 5 Preferred Web Frameworks (Want to Work With)', fontsize=15)
plt.axis('equal') 

plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
embedded_df = df['EmbeddedWantToWorkWith'].str.split(';').explode()
top_5_embedded = embedded_df.value_counts().head(5)

plt.figure(figsize=(10, 8))

colors = ['lightseagreen', 'lightcoral', 'navajowhite', 'thistle', 'powderblue']

plt.pie(
    top_5_embedded, 
    labels=top_5_embedded.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

plt.title('Top 5 Most Desired Embedded Technologies', fontsize=15, pad=20)
plt.axis('equal') 

plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
